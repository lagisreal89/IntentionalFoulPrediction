# %%
from nba_api.live.nba.endpoints import scoreboard, playbyplay

# Today's Score Board
games = scoreboard.ScoreBoard().get_dict()
first_game = games['scoreboard']['games'][0]
plays = playbyplay.PlayByPlay(game_id=first_game['gameId'])
# json
print(plays.get_json())
# dictionary
# Out:
# {"meta": {"version": 1, "code": 200, "request": "http://nba.cloud/games/0042400227/playbyplay?Format=json", "time": "2025-05-18 17:06:49.330024"}, "game": {"gameId": "0042400227", "actions": [{"actionNumber": 2, "clock": "PT12M00.00S", "timeActual": "2025-05-18T19:40:50.9Z", "period": 1, "periodType": "REGULAR", "actionType": "period", "subType": "start", "qualifiers": [], "personId": 0, "x": null, "y": null, "possession": 0, "scoreHome": "0", "scoreAway": "0", "edited": "2025-05-18T19:40:50Z", "orderNumber": 20000, "isTargetScoreLastPeriod": false, "xLegacy": null, "yLegacy": null, "isFieldGoal": 0, "side": null, "description": "Period Start", "personIdsFilter": []}, {"actionNumber": 4, "clock": "PT11M56.00S", "timeActual": "2025-05-18T19:40:54.7Z", "period": 1, "periodType": "REGULAR", "teamId": 1610612743, "teamTricode": "DEN", "actionType": "jumpball", "subType": "recovered", "descriptor": "startperiod", "qualifiers": [], "personId": 1631128, "x": null, "y": null, "possession": 1
# ...
