# %%
from nba_api.live.nba.endpoints import scoreboard, playbyplay, boxscore

# Today's Score Board and Play by Play data
games = scoreboard.ScoreBoard().get_dict()
first_game = games['scoreboard']['games'][0]
plays = playbyplay.PlayByPlay(game_id=first_game['gameId'])
print(plays.get_dict())
box_score = boxscore.BoxScore(game_id=first_game['gameId']).get_dict()
print(box_score)
# Out:
# {'meta': {'version': 1, 'code': 200, 'request': 'http://nba.cloud/games/0042400227/playbyplay?Format=json', 'time': '2025-05-18 18:23:48.713631'}, 'game': {'gameId': '0042400227', 'actions': [{'actionNumber': 2, 'clock': 'PT12M00.00S', 'timeActual': '2025-05-18T19:40:50.9Z', 'period': 1, 'periodType': 'REGULAR', 'actionType': 'period', 'subType': 'start', 'qualifiers': [], 'personId': 0, 'x': None, 'y': None, 'possession': 0, 'scoreHome': '0', 'scoreAway': '0', 'edited': '2025-05-18T19:40:50Z', 'orderNumber': 20000, 'isTargetScoreLastPeriod': False, 'xLegacy': None, 'yLegacy': None, 'isFieldGoal': 0, 'side': None, 'description': 'Period Start', 'personIdsFilter': []}, {'actionNumber': 4, 'clock': 'PT11M56.00S', 'timeActual': '2025-05-18T19:40:54.7Z', 'period': 1, 'periodType': 'REGULAR', 'teamId': 1610612743, 'teamTricode': 'DEN', 'actionType': 'jumpball', 'subType': 'recovered', 'descriptor': 'startperiod', 'qualifiers': [], 'personId': 1631128, 'x': None, 'y': None, 'possession': 1
# ...
